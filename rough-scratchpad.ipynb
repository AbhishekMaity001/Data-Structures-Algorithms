# %%
a = [1,2,3,4]
b = a

print(id(a), id(b))
# Out:
# 1979698665728 1979698665728

# %%
id(a) == id(b)
# Out:
# True

# %%
import copy

# %%
c = copy.copy(a)

# %%
print(id(a), id(c))
# Out:
# 1979698665728 1979703083712

# %%
id(a[0]), id(c[0])
# Out:
# (140712776106920, 140712776106920)

# %%
# Out:
# -2
