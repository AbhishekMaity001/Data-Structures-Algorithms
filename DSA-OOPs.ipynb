# %% [markdown]
# ## Object oriented Programming main pillars
# - Inheritance
# - Polymorphism
# - Encapsulation
# - Abstraction
#
# ## Object oriented Programming concepts
# - __ str __ vs __ repr __ , dunder magic methods
# - instance, class methods, static methods

# %%
class Human:

    lifespan=70
    eyes=2
    nose=1
    def __init__(self, name, gender=None, friend_list=None):
        """
        this is the constructor and will be executed whenever class is instantiated.
        """
        self.name = name
        self.gender = gender
        self.friend_list = friend_list if friend_list else []
        print("Human being is created")

    # defining any methods
    def add_friend(self, human):
        self.friend_list.append(human)
        human.friend_list.append(self)
        print(f"{self.name} and {human.name} are now friends...")

    def __str__(self):
        return f"{self.name} - {self.gender} -- by str"

    def __repr__(self):
        return f"{self.name} is {self.gender} -- by repr"

    def walk(self):
        print("i am walking")

    def eat(self):
        print("i am eating")

    @classmethod
    def change_lifespan(cls, new_lifespan):
        cls.lifespan = new_lifespan

    @staticmethod
    def calculate_age(yob):
        return datetime.datetime.now().year - yob

# %% [markdown]
# # Inheritance

# %%
class Employee(Human):
    
    def __init__(self, name, gender, dept, salary):
        # Inheritance, calling Human constructor
        # Human.__init__(self, name, gender)  This is not recommended way
        super().__init__(name, gender)  # calling init method of parent class
        
        self.dept = dept
        self.salary = salary

    def eat(self):
        print("i am an employee and i am eating...")

# %%
emp1 = Employee("ram", "male", "cse", 3000)
# Out:
# Human being is created

# %%
emp1.gender
# Out:
# 'male'

# %% [markdown]
# # Polymorphism
# - Using a function for more than one purposes, so when eat function is called with different instance objects, it behaves differently.
# - Any Function you call it will first search at its own level, then go to class level, then to its parent level it is inherited from
# - basically there are 2 ways to acheive overloading 1. Method overriding 2. Operator overloading
# - Example is the payment gateway, you click on payment button, by selecting the payment via UPI, NetBanking, Credit Card etc.

# %%
emp1.eat()
# Out:
# i am an employee and i am eating...

# %%
h1 = Human("ram", "male")
h1.eat()
# Out:
# Human being is created
# i am eating

# %%
h1 = Human("ram", "male")
h2 = Human("sita", "female")

# %%
h1
# Out:
# ram is male -- by repr

# %%
print(h1)
# Out:
# ram - male -- by str

# %%
print(dir(h1))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'add_friend', 'change_lifespan', 'eat', 'eyes', 'friend_list', 'gender', 'lifespan', 'name', 'nose', 'walk']

# %%
h1.add_friend(h2)
# Out:
# ram and sita are now friends...

# %%
h2.friend_list
# Out:
# [ram is male -- by repr]

# %%
h1.change_lifespan(22)

# %%
h1.lifespan
# Out:
# 22

# %%
h2.lifespan
# Out:
# 22

# %%
Human.lifespan
# Out:
# 22

# %% [markdown]
# # Abstraction --> (interface + implementation)
# - To hide the actual implementation
# - the idea behind this is , we deal with interface without worrying about implementation
# - by default in python abstraction is not implemented, there are libraries to implement that. abstract method and abstract classes
# - Abstract method ---> is a method that does not have implementation (not a concrete method)

# %%
from abc import abstractmethod, ABC

# %% [markdown]
#     This code will define what is the criteria which will define the payment method. This will actually enforce that all the payment
#     methods should have a mandatory pay and cancel methods inside it. If it does not have these methods then python will not allow only to create a class
#     Mandatory method overriding for all abstract method

# %%
class PaymentMethod(ABC):
    """
    This is the Interface
    """
    @abstractmethod
    def pay(self):
        pass

    @abstractmethod
    def cancel(self):
        pass

# %%
class CreditCardPayment(PaymentMethod):
    """
    This is the implementation of the Interface
    """
    
    def pay(self, amount):
        print("Transcation completed successfully...")
    def cancel(self):
        print("Transcation cancelled...")

class UPIPayment(PaymentMethod):
    """
    This is the implementation of the Interface
    """
    
    def pay(self):
        print("Transcation completed successfully...")
    def cancel(self):
        print("Transcation cancelled...")

class InternetBankingPayment(PaymentMethod):
    """
    This is the implementation of the Interface
    """
    
    # def pay(self):
    #     print("Transcation completed successfully...")
    # def cancel(self):
    #     print("Transcation cancelled...")

    def make_payment(self):
        print("Transcation completed successfully...")
    def cancel_payment(self):
        print("Transcation cancelled...")

# %%
ccpayment = CreditCardPayment()

# %%
upipayment = UPIPayment()

# %%
internetbanking = InternetBankingPayment()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[190], line 1
# ----> 1 internetbanking = InternetBankingPayment()
#
# TypeError: Can't instantiate abstract class InternetBankingPayment without an implementation for abstract methods 'cancel', 'pay'

# %% [markdown]
# # Encapsulation
# - Bundling the methods and variables together
# - protecting the access to certain methods and attributes
# - public , protected and private variables (it is just a naming convention, single underscore means protected and double underscore means private)
#
#
#
#         We cannot access the private attributes directly because of name mangling, but if we forcefully want then we can do it, by just
#         print the object with obj_name.__dict__
#
#            it will be generally, _BankAccount__balance - this means python makes it private by modifying the name internally
#
#           We can use getter and setter methods, which needs some authentication. in order to really protect the variables undergoing modification

# %%
class BankAccount:
    def __init__(self, account_number, branch_name, account_holder, balance):
        self.account_number = account_number
        self.account_holder = account_holder

        # adding a underscore indicates this is a protected attribute
        self.__
            balance = balance  ## this is private/protected attribute, we need to control the access to this.
        self.branch_name = branch_name

    def deposit(self, amount):
        """
        Need to add some balance
        """
        pass

    def withdraw(self, amount):
        """
        Need to withdraw some money
        """
        pass

# %% [markdown]
# ### C3 linearization algorithm
#         Which decides which class should come first, how super flow will happen.
#         Method Resolution Order

# %%
help(BankAccount)
# Out:
# Help on class BankAccount in module __main__:
#
# class BankAccount(builtins.object)
#  |  BankAccount(account_number, branch_name, account_holder, balance)
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, account_number, branch_name, account_holder, balance)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  deposit(self, amount)
#  |      Need to add some balance
#  |
#  |  withdraw(self, amount)
#  |      Need to withdraw some money
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
myaccount = BankAccount(account_number=1234, account_holder="Ram", branch_name="Jamshedpur", balance=8000)

# %%
myaccount.balance, myaccount.account_holder
# Out:
# (8000, 'Ram')

# %% [markdown]
# # Some example of static method and class method
#
#         - class attributes --> those attributes which belongs to the class .. shared by all instances of the class
#         - class methods --> those methods which allow us to make changes to the class attributes (they are also alternate constructors)
#         - static methods --> utility method that dont take class or instance as parameters, they are general purpose utility methods that is kept in the class bcoz its logically connected to the class

# %% [markdown]
# # @property decorator
#
#         - getter, setters and deleters

# %%
class Employee:
    def __init__(self, fname, lname, salary):
        self.fname = fname
        self.lname = lname
        self.salary = salary
        # self.email = f"{self.fname}.{self.lname}@mycompany.com"

    @property
    def email(self):
        """
        This is a getter, which will get the value dynamically.
        """
        return f"{self.fname}.{self.lname}@mycompany.com"

    @email.setter
    def email(self, val):
        """
        This is a setter, which is mandatory when you want to set some value
        """
        self._email = f"{val}@mycompany.com"

# %%
e1 = Employee(fname="ram", lname="kumar", salary=3000)

# %%
e1.fname, e1.lname, e1.email
# Out:
# ('ram', 'kumar', 'ram.kumar@mycompany.com')

# %%
e1.fname = "rammm"

e1.fname, e1.email
# Out:
# ('rammm', 'rammm.kumar@mycompany.com')

# %% [markdown]
# #### This is getter, we are trying to accessing the balance method but like an attribute

# %%
e1.email
# Out:
# 'rammm.kumar@mycompany.com'

# %%
e1.email = "zzz"
